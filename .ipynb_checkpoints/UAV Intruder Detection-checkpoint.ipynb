# %% [markdown]
# # Analise descritiva de dados - Projeto detecção de drones intrusos
# ### Principais topicos (Aula 2)
# * Caracterizacao de dados:
#  *  Tipo e escala
#  *  Tipos de Dados
# * Exploração de dados:
#  *  Estatistica descritiva
#  *  Captura de informacoes como: Frequência, Localizaçao ou tendência central, Dispersao ou espalhamento, Distribuicao ou formato
#  * Ferramentas de visualização (por ex.: Boxplots, Histogramas, Grafico de pizza, Scatter plots, Heatmaps ... )

# %% [markdown]
# # Analise 1 Unidirectional Flow: Dataset 4,5 e 6

# %%
import pandas as pd

# %%
lista = ['V1_size','V2_size','V3_size','V4_size','V5_size','V6_size','V7_size','V8_size','V9_size','V1_interval','V2_interval','V3_interval','V4_interval','V5_interval','V6_interval','V7_interval','V8_interval','V9_interval','classe']

# %%
#lista = ['Mean_uplink_size','Median_uplink_size','MAD_uplink_size','STD_uplink_size','Skewness_uplink_size','V6_uplink_size','V7_uplink_size','V8_uplink_size','V9_uplink_size','V1_uplink_interval','V2_uplink_interval','V3_uplink_interval','V4_uplink_interval','V5_uplink_interval','V6_uplink_interval','V7_uplink_interval','V8_uplink_interval','V9_uplink_interval','classe']

# %%
df_test_4= pd.read_csv('./dataset/dataset4_teste.csv', sep = ',', names=lista)

# %%
df_test_5= pd.read_csv('./dataset/dataset5_teste.csv', sep = ',', names=lista)

# %%
df_test_6= pd.read_csv('./dataset/dataset6_teste.csv', sep = ',', names=lista)

# %%
df_train_4= pd.read_csv('./dataset/dataset4_treino.csv', sep = ',', names=lista)

# %%
df_train_5= pd.read_csv('./dataset/dataset5_treino.csv', sep = ',', names=lista)

# %%
df_train_6= pd.read_csv('./dataset/dataset6_treino.csv', sep = ',', names=lista)

# %%
print("Tamanho df teste 4 : ",len(df_test_4))
print("Tamanho df treino 4 : ",len(df_train_4))
print("Tamanho df teste 5 : ",len(df_test_5))
print("Tamanho df treino 5 : ",len(df_train_5))
print("Tamanho df teste 6 : ",len(df_test_6))
print("Tamanho df treino 6 : ", len(df_train_6))
# Out:
# Tamanho df teste 4 :  1063
# Tamanho df treino 4 :  10600
# Tamanho df teste 5 :  1351
# Tamanho df treino 5 :  13513
# Tamanho df teste 6 :  7
# Tamanho df treino 6 :  66

# %% [markdown]
# ## Concatenando os dataframes 4,5 e 6:

# %%
frames = [df_train_4,df_test_4, df_train_5, df_test_5, df_train_6, df_test_6]
df_train1 = pd.concat(frames)

# %%
len(df_train1)
# Out:
# 26600

# %%
df_train1.head()
# Out:
#     V1_size   V2_size   V3_size   V4_size  V5_size   V6_size   V7_size  \
# 0  0.000438  0.002101  0.000006  0.000003   6.5008  42.76100  0.016319
# 1  0.000388  0.000783  0.000130  0.000090   2.4140   3.95440  0.002615
# 2  0.000142  0.000174  0.000100  0.000147   1.3829   0.91272  0.000585
# 3  0.000645  0.001331  0.000145  0.000073   3.9211  21.45700  0.009911
# 4  0.000171  0.000218  0.000126  0.000053   2.6358   6.42960  0.000961
#
#     V8_size   V9_size  V1_interval  V2_interval  V3_interval  V4_interval  \
# 0  0.000003  0.002136       759.62      477.050       1130.0        0.000
# 1  0.000000  0.000870        86.32       35.631         62.0        0.000
# 2  0.000000  0.000224       103.47       40.320        138.0       22.239
# 3  0.000007  0.001473        81.76       33.504         62.0        0.000
# 4  0.000003  0.000277        86.32       35.631         62.0        0.000
#
#    V5_interval  V6_interval  V7_interval  V8_interval  V9_interval  classe
# 0    -0.505190     -1.74200         1130           61      895.730       1
# 1     0.760200     -1.43620          138           62       93.317       1
# 2    -0.036313     -1.95700          153           62      110.970       1
# 3     1.077900     -0.84623          138           62       88.295       1
# 4     0.760200     -1.43620          138           62       93.317       1

# %% [markdown]
# ### Substituindo 0 e 1 como Other e UAV

# %%
df_train1['classe'] = df_train1['classe'].replace([1],'VANT')

# %%
df_train1['classe'] = df_train1['classe'].replace([0],'Outro')

# %%
df_train1.head()
# Out:
#     V1_size   V2_size   V3_size   V4_size  V5_size   V6_size   V7_size  \
# 0  0.000438  0.002101  0.000006  0.000003   6.5008  42.76100  0.016319
# 1  0.000388  0.000783  0.000130  0.000090   2.4140   3.95440  0.002615
# 2  0.000142  0.000174  0.000100  0.000147   1.3829   0.91272  0.000585
# 3  0.000645  0.001331  0.000145  0.000073   3.9211  21.45700  0.009911
# 4  0.000171  0.000218  0.000126  0.000053   2.6358   6.42960  0.000961
#
#     V8_size   V9_size  V1_interval  V2_interval  V3_interval  V4_interval  \
# 0  0.000003  0.002136       759.62      477.050       1130.0        0.000
# 1  0.000000  0.000870        86.32       35.631         62.0        0.000
# 2  0.000000  0.000224       103.47       40.320        138.0       22.239
# 3  0.000007  0.001473        81.76       33.504         62.0        0.000
# 4  0.000003  0.000277        86.32       35.631         62.0        0.000
#
#    V5_interval  V6_interval  V7_interval  V8_interval  V9_interval classe
# 0    -0.505190     -1.74200         1130           61      895.730   VANT
# 1     0.760200     -1.43620          138           62       93.317   VANT
# 2    -0.036313     -1.95700          153           62      110.970   VANT
# 3     1.077900     -0.84623          138           62       88.295   VANT
# 4     0.760200     -1.43620          138           62       93.317   VANT

# %% [markdown]
# ## Analisando se existem campos vazios ou com NaN

# %%
df_train1.isnull().values.any()
# Out:
# False

# %%
df_train1.isnull().sum()
# Out:
# V1_size        0
# V2_size        0
# V3_size        0
# V4_size        0
# V5_size        0
# V6_size        0
# V7_size        0
# V8_size        0
# V9_size        0
# V1_interval    0
# V2_interval    0
# V3_interval    0
# V4_interval    0
# V5_interval    0
# V6_interval    0
# V7_interval    0
# V8_interval    0
# V9_interval    0
# classe         0
# dtype: int64

# %%
print(df_train1.shape)
print(df_train1.dropna().shape)
# Out:
# (26600, 19)
# (26600, 19)

# %% [markdown]
# ### Podemos notar que não ha valores faltantes ou NaN

# %% [markdown]
# # Investigando o balanceamento dos dados

# %%
import seaborn as sns

# %%
df_train1.classe.value_counts(normalize=True).round(3)
# Out:
# VANT     0.533
# Outro    0.467
# Name: classe, dtype: float64

# %%
targets= df_train1.classe.to_numpy()

# %%
from collections import Counter
print(Counter(targets))
# Out:
# Counter({'VANT': 14171, 'Outro': 12429})

# %% [markdown]
# ## Vemos que 53% dos objetos são do tipo UAV e 46,7% deles são não UAV

# %%
import matplotlib.pyplot as plt
sns.set(font_scale=1.3)
sns.set(rc={'figure.figsize':(8,8)})
ax = sns.countplot(x="classe", data=df_train1)
fig = ax.get_figure()
fig.savefig("balanceamento_Datasets_456.png")

# %% [markdown]
# ### Investigando dados estatisticos: médias, desvios padrão, quartis q1, q2 e q3, valores maximos, kurtose, obliquidade

# %%
df_train1.describe().round(4)
# Out:
#           V1_size     V2_size     V3_size     V4_size     V5_size     V6_size  \
# count  26600.0000  26600.0000  26600.0000  26600.0000  26600.0000  26600.0000
# mean       0.1413      0.8321      0.0092      0.0054      4.0116     23.1255
# std        2.3531     21.3945      0.5917      0.0485      2.2606     23.7243
# min        0.0001      0.0000      0.0000      0.0000     -1.9319     -1.9807
# 25%        0.0013      0.0025      0.0001      0.0001      2.3231      5.7673
# 50%        0.0033      0.0082      0.0003      0.0002      3.4637     13.7380
# 75%        0.0122      0.0267      0.0009      0.0008      5.4842     33.7100
# max      149.8700   1492.4000     68.1710      3.9419      9.8493     98.0100
#
#           V7_size     V8_size     V9_size  V1_interval  V2_interval  \
# count  26600.0000  26600.0000  26600.0000   26600.0000   26600.0000
# mean       7.5087      0.0001      0.8450     746.7540     351.6730
# std      213.3520      0.0001     21.4168     514.2398     264.5077
# min        0.0002      0.0000      0.0001      63.5200       0.2000
# 25%        0.0166      0.0000      0.0029     123.1475      40.3760
# 50%        0.0477      0.0000      0.0093     866.2550     359.4900
# 75%        0.1515      0.0001      0.0289    1141.1250     618.9500
# max    14925.0000      0.0082   1492.5000    1675.7000     761.0700
#
#        V3_interval  V4_interval  V5_interval  V6_interval  V7_interval  \
# count   26600.0000    26600.000   26600.0000   26600.0000   26600.0000
# mean      863.5097       97.517      -0.5053       4.6564    1121.2766
# std       657.7561      192.386       2.2341      14.1061     658.1798
# min        62.0000        0.000      -9.7020      -2.0199      68.0000
# 25%       138.0000        0.000      -1.0159      -1.2723     183.0000
# 50%      1166.0000        0.000      -0.3316       1.1759    1502.0000
# 75%      1476.0000      112.680       0.5807       2.2490    1610.0000
# max      1676.0000     1136.400       9.8494      98.0100    3468.0000
#
#        V8_interval  V9_interval
# count   26600.0000   26600.0000
# mean      167.1006     842.8334
# std       151.6565     550.8321
# min        61.0000      63.9810
# 25%        76.0000     130.6400
# 50%        76.0000    1083.4000
# 75%       222.0000    1285.5000
# max      1676.0000    1675.7000

# %%
df_train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26600 entries, 0 to 6
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   V1_size      26600 non-null  float64
#  1   V2_size      26600 non-null  float64
#  2   V3_size      26600 non-null  float64
#  3   V4_size      26600 non-null  float64
#  4   V5_size      26600 non-null  float64
#  5   V6_size      26600 non-null  float64
#  6   V7_size      26600 non-null  float64
#  7   V8_size      26600 non-null  float64
#  8   V9_size      26600 non-null  float64
#  9   V1_interval  26600 non-null  float64
#  10  V2_interval  26600 non-null  float64
#  11  V3_interval  26600 non-null  float64
#  12  V4_interval  26600 non-null  float64
#  13  V5_interval  26600 non-null  float64
#  14  V6_interval  26600 non-null  float64
#  15  V7_interval  26600 non-null  int64
#  16  V8_interval  26600 non-null  int64
#  17  V9_interval  26600 non-null  float64
#  18  classe       26600 non-null  object
# dtypes: float64(16), int64(2), object(1)
# memory usage: 4.7+ MB

# %%
description = df_train1.describe().round(4)

# %%
description.to_csv("my_description456linha.csv")

# %%
df_train1.var()
# Out:
# V1_size        5.536965e+00
# V2_size        4.577255e+02
# V3_size        3.500920e-01
# V4_size        2.351920e-03
# V5_size        5.110250e+00
# V6_size        5.628427e+02
# V7_size        4.551910e+04
# V8_size        2.030163e-08
# V9_size        4.586790e+02
# V1_interval    2.644426e+05
# V2_interval    6.996434e+04
# V3_interval    4.326431e+05
# V4_interval    3.701237e+04
# V5_interval    4.990980e+00
# V6_interval    1.989807e+02
# V7_interval    4.332006e+05
# V8_interval    2.299970e+04
# V9_interval    3.034161e+05
# dtype: float64

# %%
skewness = df_train1.skew().round(4)

# %%
df_train1.skew().round(4)
# Out:
# V1_size         42.3114
# V2_size         48.1196
# V3_size        114.9621
# V4_size         47.2162
# V5_size          0.7266
# V6_size          1.3725
# V7_size         48.4269
# V8_size         20.7556
# V9_size         48.0160
# V1_interval      0.0228
# V2_interval      0.0022
# V3_interval     -0.0752
# V4_interval      2.7070
# V5_interval     -0.8213
# V6_interval      4.4754
# V7_interval     -0.7094
# V8_interval      3.9658
# V9_interval     -0.2779
# dtype: float64

# %%
skewness.to_csv("skeness456linha.csv")

# %%
df_train1.kurtosis()
# Out:
# V1_size         1986.326023
# V2_size         2558.709610
# V3_size        13242.331810
# V4_size         3410.116712
# V5_size           -0.218241
# V6_size            1.012844
# V7_size         2585.214505
# V8_size          979.722630
# V9_size         2549.394717
# V1_interval       -1.367117
# V2_interval       -1.614993
# V3_interval       -1.823425
# V4_interval        7.930638
# V5_interval        4.768366
# V6_interval       22.253497
# V7_interval       -1.405862
# V8_interval       24.735536
# V9_interval       -1.531201
# dtype: float64

# %% [markdown]
# # Investigando correlações:

# %% [markdown]
# # I) Scatter plots

# %% [markdown]
# ## Correlações _size - _interval

# %%
y= df_train1.classe.to_numpy()

# %%
y
# Out:
# array(['VANT', 'VANT', 'VANT', ..., 'VANT', 'VANT', 'VANT'], dtype=object)

# %%
print(df_train1.keys())
# Out:
# Index(['V1_size', 'V2_size', 'V3_size', 'V4_size', 'V5_size', 'V6_size',
#        'V7_size', 'V8_size', 'V9_size', 'V1_interval', 'V2_interval',
#        'V3_interval', 'V4_interval', 'V5_interval', 'V6_interval',
#        'V7_interval', 'V8_interval', 'V9_interval', 'classe'],
#       dtype='object')

# %% [markdown]
# ## Uplink_size: Grafico Matriz de scatterplot

# %%
import numpy as np

attributes = lista
attributes = attributes[0:9]

plt.style.use('ggplot')
colors_palette = {'Outro': 'blue', 'VANT': 'green'}
groups = list(y)
colors = [colors_palette[c] for c in groups]

axes = pd.plotting.scatter_matrix(df_train1[attributes],c=colors,figsize=[12,12],s=30,marker='D')


for ax in axes.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_ha('right')

plt.savefig("ScatterMatrix1_Datasets_456.png")

# %% [markdown]
# # Uplink_interval

# %%
attributes = lista
attributes = attributes[9:18]
plt.style.use('ggplot')
colors_palette = {'Outro': 'blue', 'VANT': 'green'}
groups = list(y)
colors = [colors_palette[c] for c in groups]

axes = pd.plotting.scatter_matrix(df_train1[attributes],c=colors,figsize=[12,12],s=30,marker='D')

for ax in axes.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_ha('right')
plt.savefig("ScatterMatrix3_Datasets_456.png")

# %% [markdown]
# ## 2) Investigando correlações em Heatmaps

# %%
df_train1['classe'] = df_train1['classe'].replace('VANT',1)

# %%
df_train1['classe'] = df_train1['classe'].replace('Outro',0)

# %%
y= df_train1.classe.to_numpy()

# %%
#df_train1 = df_train1.drop(['classe'], axis=1)

# %%
df_train1.head()
# Out:
#     V1_size   V2_size   V3_size   V4_size  V5_size   V6_size   V7_size  \
# 0  0.000438  0.002101  0.000006  0.000003   6.5008  42.76100  0.016319
# 1  0.000388  0.000783  0.000130  0.000090   2.4140   3.95440  0.002615
# 2  0.000142  0.000174  0.000100  0.000147   1.3829   0.91272  0.000585
# 3  0.000645  0.001331  0.000145  0.000073   3.9211  21.45700  0.009911
# 4  0.000171  0.000218  0.000126  0.000053   2.6358   6.42960  0.000961
#
#     V8_size   V9_size  V1_interval  V2_interval  V3_interval  V4_interval  \
# 0  0.000003  0.002136       759.62      477.050       1130.0        0.000
# 1  0.000000  0.000870        86.32       35.631         62.0        0.000
# 2  0.000000  0.000224       103.47       40.320        138.0       22.239
# 3  0.000007  0.001473        81.76       33.504         62.0        0.000
# 4  0.000003  0.000277        86.32       35.631         62.0        0.000
#
#    V5_interval  V6_interval  V7_interval  V8_interval  V9_interval  classe
# 0    -0.505190     -1.74200         1130           61      895.730       1
# 1     0.760200     -1.43620          138           62       93.317       1
# 2    -0.036313     -1.95700          153           62      110.970       1
# 3     1.077900     -0.84623          138           62       88.295       1
# 4     0.760200     -1.43620          138           62       93.317       1

# %%
#from sklearn.preprocessing import Normalizer
#normalizeddf_train = Normalizer().fit_transform(df_train1)

# %%
#normalizeddf_train

# %% [markdown]
# ## 1: Correlações de Pearson

# %%
import seaborn as sns

sns.set(font_scale=1.3)

corr = df_train1.corr(method = 'pearson')
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='center'
);



sns.set(rc={'figure.figsize':(8,8)})

fig = ax.get_figure()
fig.savefig("Heatmap_Datasets_456_pearson_improved.png")

# %% [markdown]
# ## Correlações de Spearman

# %%
import seaborn as sns

sns.set(font_scale=1.2)

corr = df_train1.corr(method = 'spearman')
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

sns.set(rc={'figure.figsize':(10,10)})

fig = ax.get_figure()
fig.savefig("Heatmap_Datasets_456_spearman_improved.png")

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# ## Abordagens utilizadas
# - Dados desbalanceados
# - Normalização: Na tabela de dados estatisticos, podemos notar que os valores dos atributos estão em escalas bastante diferentes. ("Outra transformação muito utilizada é a normalização de dados. A normalização de dados é recomendável quando os limites de valores de atributos distintos são muito diferentes, para evitar que um atributo predomine sobre outro (a menos que isso seja importante")
# - Redução de dimensionalidade? Verificar a importância de cada atributo (Agregação ou seleção de atributos)

# %% [markdown]
# ## 1 - Dropando valores duplicados

# %%
df_train_noduplicates = df_train1.drop_duplicates()

# %%
print(f'Resultante sem duplicados {df_train_noduplicates.shape}')
print(f'Resultante sem duplicados {df_train_noduplicates.shape}')
print(f'Total de valores duplicados: {df_train_noduplicates.shape[0]-df_train1.shape[0]}')
# Out:
# Resultante sem duplicados (23181, 19)
# Resultante sem duplicados (23181, 19)
# Total de valores duplicados: -3419

# %%
df_train_noduplicates.classe.value_counts(normalize=True).round(3)
# Out:
# 1    0.611
# 0    0.389
# Name: classe, dtype: float64

# %%
df_train_noduplicates
# Out:
#      V1_size   V2_size   V3_size   V4_size  V5_size   V6_size   V7_size  \
# 0   0.000438  0.002101  0.000006  0.000003   6.5008  42.76100  0.016319
# 1   0.000388  0.000783  0.000130  0.000090   2.4140   3.95440  0.002615
# 2   0.000142  0.000174  0.000100  0.000147   1.3829   0.91272  0.000585
# 3   0.000645  0.001331  0.000145  0.000073   3.9211  21.45700  0.009911
# 4   0.000171  0.000218  0.000126  0.000053   2.6358   6.42960  0.000961
# ..       ...       ...       ...       ...      ...       ...       ...
# 2   0.003500  0.004243  0.002131  0.002714   4.0474  29.20800  0.034427
# 3   0.000685  0.000879  0.000517  0.000022   6.0298  39.52300  0.006628
# 4   0.009514  0.089832  0.000515  0.000006   9.8493  98.01000  0.898850
# 5   0.009842  0.093143  0.000516  0.000008   9.8493  98.01000  0.931960
# 6   0.003114  0.004620  0.000653  0.000765   4.0433  28.22500  0.036471
#
#      V8_size   V9_size  V1_interval  V2_interval  V3_interval  V4_interval  \
# 0   0.000003  0.002136       759.62     477.0500       1130.0        0.000
# 1   0.000000  0.000870        86.32      35.6310         62.0        0.000
# 2   0.000000  0.000224       103.47      40.3200        138.0       22.239
# 3   0.000007  0.001473        81.76      33.5040         62.0        0.000
# 4   0.000003  0.000277        86.32      35.6310         62.0        0.000
# ..       ...       ...          ...          ...          ...          ...
# 2   0.000006  0.005484       112.70      38.2390        109.5       49.667
# 3   0.000399  0.001110        85.80       1.4071         86.0        0.000
# 4   0.000282  0.089887        87.58      11.1160         86.0        0.000
# 5   0.000223  0.093197        87.41       8.0580         86.0        0.000
# 6   0.000015  0.005552        96.80      27.3650         86.0       14.826
#
#     V5_interval  V6_interval  V7_interval  V8_interval  V9_interval  classe
# 0     -0.505190     -1.74200         1130           61      895.730       1
# 1      0.760200     -1.43620          138           62       93.317       1
# 2     -0.036313     -1.95700          153           62      110.970       1
# 3      1.077900     -0.84623          138           62       88.295       1
# 4      0.760200     -1.43620          138           62       93.317       1
# ..          ...          ...          ...          ...          ...     ...
# 2      0.249610      1.33320          165           76      118.950       1
# 3     -6.857100     48.02000           86           76       85.811       1
# 4      6.857100     48.02000          165           86       88.276       1
# 5      5.510400     31.36400          133           86       87.777       1
# 6      1.193900      2.56590          146           76      100.560       1
#
# [23181 rows x 19 columns]

# %%
y= df_train_noduplicates.classe.to_numpy()

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
df_train_noduplicates = df_train_noduplicates.drop(['classe'], axis=1)

# %% [markdown]
# ### 1 - Lidando com o desbalanceamento (eliminando artificialmente alguns exemplos da classe majoritaria)

# %% [markdown]
# Aqui, utilizei "random undersampling", técnica que permite retirar aleatoriamente dados da classe majoritaria e, assim, balancear os dados

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
undersample = RandomUnderSampler(sampling_strategy='majority')

# %%
X_balanced, y_balanced = undersample.fit_resample(df_train_noduplicates, y)

# %%
from collections import Counter

# %%
print(Counter(y_balanced))
# Out:
# Counter({0: 9010, 1: 9010})

# %%
X_balanced
# Out:
#         V1_size   V2_size   V3_size   V4_size  V5_size  V6_size    V7_size  \
# 0      0.007135  0.013277  0.002182  0.002751   2.9692   9.4991   0.074816
# 1      0.167980  0.473860  0.003873  0.005562   4.6972  23.4240   3.183600
# 2      0.100310  0.736630  0.000345  0.000420   9.6209  91.9940   7.372600
# 3      0.689110  1.934400  0.000215  0.000116   4.7959  29.1920  15.070000
# 4      0.039378  0.158930  0.001014  0.001090   7.2926  58.1530   1.432700
# ...         ...       ...       ...       ...      ...      ...        ...
# 18015  0.002191  0.005515  0.000032  0.000040   2.6835   8.8583   0.022474
# 18016  0.010069  0.012101  0.005631  0.008118   1.4867   4.6402   0.047301
# 18017  0.002482  0.013404  0.000017  0.000018   8.6752  81.6470   0.129190
# 18018  0.000286  0.001052  0.000005  0.000001   7.7561  67.5790   0.009925
# 18019  0.002541  0.007821  0.000144  0.000204   4.1310  21.0270   0.048277
#
#         V8_size   V9_size  V1_interval  V2_interval  V3_interval  V4_interval  \
# 0      0.000119  0.015014       340.48      346.470        222.0       0.0000
# 1      0.000119  0.500520       315.01      201.400        241.0      28.1690
# 2      0.000125  0.739770       400.63      275.310        224.0       2.9652
# 3      0.000111  2.044300       359.96      225.750        262.5      60.0450
# 4      0.000117  0.162960      1127.70      591.530       1588.0      11.8610
# ...         ...       ...          ...          ...          ...          ...
# 18015  0.000004  0.005909       968.87      723.500       1602.0      11.8610
# 18016  0.000004  0.015696       133.76       43.229        168.0      19.2740
# 18017  0.000002  0.013566      1180.90      625.870       1550.0      47.4430
# 18018  0.000004  0.001085       130.40       22.915        138.0       0.0000
# 18019  0.000002  0.008186       953.77      631.740       1346.0     171.9800
#
#        V5_interval  V6_interval  V7_interval  V8_interval  V9_interval
# 0          2.85780       6.3813         1476          222       484.53
# 1          4.11870      19.6590         1476          222       373.35
# 2          1.38140       0.8520         1160          222       485.33
# 3          2.02610       3.3624         1111          222       424.29
# 4         -0.59074      -1.5450         1596          228      1272.10
# ...            ...          ...          ...          ...          ...
# 18015     -0.31769       1.1904         1610           76      1207.00
# 18016     -0.12548       1.0649          183           86       140.51
# 18017     -1.12990       2.3489         1606           76      1335.00
# 18018     -2.62680       4.9497          138           62       132.38
# 18019     -0.60963       1.4533         1594           76      1142.30
#
# [18020 rows x 18 columns]

# %% [markdown]
# ### Normalização

# %% [markdown]
# "A normalização pode ser por amplitude ou por distribuição"
# - "Normalização por amplitude: Pode ser por reescala ou por padronização. . A primeira define uma nova escala de valores, limites mínimo e máximo, para todos os atributos. A segunda define um valor central e um valor de espalhamento comuns para todos os atributos."
# - Para a normalização por padronização, a cada valor do atributo a ser normalizado é adicionada ou subtraída uma medida de localização e o valor resultante é em seguida multiplicado ou dividido por uma medida de escala. Com isso, diferentes atributos podem ter limites inferiores e superiores distintos, mas terão os mesmos valores para as medidas de escala e espalhamento

# %% [markdown]
# ### Como decidir qual usar?
# ![image.png](attachment:image.png)
#
#
# Source: https://www.analyticsvidhya.com/blog/2020/04/feature-scaling-machine-learning-normalization-standardization/

# %% [markdown]
# #### Usando normalização:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Usando standardization

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = StandardScaler()
Xstd = scaler.fit_transform(X_balanced)
df_balanced_stand = pd.DataFrame(Xstd, columns=X_balanced.columns, index=X_balanced.index)
df_balanced_stand.head()
# Out:
#     V1_size   V2_size   V3_size   V4_size   V5_size   V6_size   V7_size  \
# 0 -0.059393 -0.039944 -0.011664 -0.060351 -0.480195 -0.587036 -0.036365
# 1  0.008035 -0.018650 -0.008338 -0.000452  0.285067 -0.000631 -0.021943
# 2 -0.020333 -0.006502 -0.015274 -0.110030  2.465577  2.886987 -0.002509
# 3  0.226498  0.048874 -0.015531 -0.116491  0.328778  0.242271  0.033200
# 4 -0.045876 -0.033210 -0.013960 -0.095734  1.434466  1.461875 -0.030065
#
#     V8_size   V9_size  V1_interval  V2_interval  V3_interval  V4_interval  \
# 0  0.263453 -0.040439    -0.822544    -0.026474    -0.997008    -0.502028
# 1  0.263453 -0.018017    -0.871971    -0.583341    -0.968079    -0.354081
# 2  0.307147 -0.006968    -0.705816    -0.299629    -0.993963    -0.486455
# 3  0.205194  0.053279    -0.784741    -0.489871    -0.935344    -0.186665
# 4  0.248888 -0.033606     0.705142     0.914217     1.082831    -0.439733
#
#    V5_interval  V6_interval  V7_interval  V8_interval  V9_interval
# 0     1.468886     0.096676     0.512123     0.309814    -0.684832
# 1     2.015674     1.006300     0.512123     0.309814    -0.887559
# 2     0.828647    -0.282123     0.025232     0.309814    -0.683374
# 3     1.108220    -0.110142    -0.050266     0.309814    -0.794674
# 4    -0.026570    -0.446336     0.697018     0.348540     0.751227

# %%
df_balanced_stand.describe()
# Out:
#             V1_size       V2_size       V3_size       V4_size       V5_size  \
# count  1.802000e+04  1.802000e+04  1.802000e+04  1.802000e+04  1.802000e+04
# mean   1.204068e-16  5.768947e-17  3.260414e-17 -9.561195e-18  1.402210e-15
# std    1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00
# min   -6.236022e-02 -4.055584e-02 -1.595173e-02 -1.189708e-01 -2.650696e+00
# 25%   -6.179056e-02 -4.042957e-02 -1.571284e-02 -1.172964e-01 -7.476821e-01
# 50%   -6.094211e-02 -4.016252e-02 -1.528423e-02 -1.150253e-01 -2.270560e-01
# 75%   -5.686958e-02 -3.919089e-02 -1.409056e-02 -1.004769e-01  6.509471e-01
# max    6.276455e+01  6.895645e+01  1.340155e+02  8.387756e+01  2.566682e+00
#
#             V6_size       V7_size       V8_size       V9_size   V1_interval  \
# count  1.802000e+04  1.802000e+04  1.802000e+04  1.802000e+04  1.802000e+04
# mean  -2.419364e-16 -1.203421e-16  4.388209e-15  1.243090e-16 -9.749631e-16
# std    1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00
# min   -1.070473e+00 -3.671073e-02 -6.031432e-01 -4.112666e-02 -1.360014e+00
# 25%   -7.332847e-01 -3.662463e-02 -5.874352e-01 -4.098324e-02 -1.238227e+00
# 50%   -3.811549e-01 -3.648071e-02 -4.793438e-01 -4.068990e-02  2.150023e-01
# 75%    4.540413e-01 -3.583696e-02  2.998644e-01 -3.964476e-02  8.088672e-01
# max    3.140206e+00  6.920283e+01  5.935947e+01  6.888631e+01  1.768595e+00
#
#         V2_interval   V3_interval   V4_interval   V5_interval   V6_interval  \
# count  1.802000e+04  1.802000e+04  1.802000e+04  1.802000e+04  1.802000e+04
# mean  -1.838091e-16  7.324884e-15  9.324555e-15 -2.559809e-16  4.165015e-16
# std    1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00
# min   -1.355669e+00 -1.240621e+00 -5.020281e-01 -3.977660e+00 -4.788702e-01
# 25%   -1.200186e+00 -1.124905e+00 -5.020281e-01 -2.636288e-01 -4.258744e-01
# 50%    4.056783e-02  4.829361e-01 -5.020281e-01  8.262485e-02 -2.596938e-01
# 75%    9.995105e-01  9.123027e-01  6.252120e-02  4.887557e-01 -1.679021e-01
# max    1.565015e+00  1.216818e+00  5.466470e+00  4.436867e+00  6.034828e+00
#
#         V7_interval   V8_interval   V9_interval
# count  1.802000e+04  1.802000e+04  1.802000e+04
# mean   1.032415e-15 -5.801525e-15  1.674890e-15
# std    1.000028e+00  1.000028e+00  1.000028e+00
# min   -1.657312e+00 -7.293433e-01 -1.451664e+00
# 25%   -1.416949e+00 -6.325274e-01 -1.325249e+00
# 50%    5.829992e-01 -1.355393e-01  4.197319e-01
# 75%    7.185889e-01  3.098136e-01  8.194680e-01
# max    3.581380e+00  9.694498e+00  1.487153e+00

# %% [markdown]
# ## Seleção de atributos

# %%
df_balanced_norm.var()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-283c05dc4742> in <module>
# ----> 1 df_balanced_norm.var()
#
# NameError: name 'df_balanced_norm' is not defined

# %% [markdown]
# ### Mutual information test
# - OBS.: Advantage of using mutual information over F-Test is, it does well with the non-linear relationship between feature and target variable.
#
# Mutual Information between two variables measures the dependence of one variable to another. If X and Y are two variables, and
# If X and Y are independent, then no information about Y can be obtained by knowing X or vice versa. Hence their mutual information is 0.
# If X is a deterministic function of Y, then we can determine X from Y and Y from X with mutual information 1.
# When we have Y = f(X,Z,M,N), 0 < mutual information < 1
# We can select our features from feature space by ranking their mutual information with the target variable.
#
# Source: https://towardsdatascience.com/why-how-and-when-to-apply-feature-selection-e9c69adfabf2

# %%
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from matplotlib import pyplot
 
# feature selection
def select_features(X_train, y_train, X_test):
	# configure to select all features
	fs = SelectKBest(score_func=mutual_info_classif, k='all')
	# learn relationship from training data
	fs.fit(X_train, y_train)
	# transform train input data
	X_train_fs = fs.transform(X_train)
	# transform test input data
	X_test_fs = fs.transform(X_test)
	return X_train_fs, X_test_fs, fs
 
# load the dataset
X = df_balanced_stand
y = y_balanced

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# what are scores for the features
for i in range(len(fs.scores_)):
	print('Feature %d: %f' % (i, fs.scores_[i]))
# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# Feature 0: 0.365493
# Feature 1: 0.352680
# Feature 2: 0.464521
# Feature 3: 0.250017
# Feature 4: 0.110426
# Feature 5: 0.099040
# Feature 6: 0.419629
# Feature 7: 0.673922
# Feature 8: 0.365099
# Feature 9: 0.506880
# Feature 10: 0.442941
# Feature 11: 0.614530
# Feature 12: 0.124961
# Feature 13: 0.337164
# Feature 14: 0.417427
# Feature 15: 0.666892
# Feature 16: 0.693561
# Feature 17: 0.487812

# %%
fs.scores_
ind = 1
tup = []
for i in fs.scores_:
    tup.append((round(i,6),ind))
    ind +=1

tup.sort()   
# Retorna as features priorizadas
for i in reversed(tup):
    print(i)
# Out:
# (0.693561, 17)
# (0.673922, 8)
# (0.666892, 16)
# (0.61453, 12)
# (0.50688, 10)
# (0.487812, 18)
# (0.464521, 3)
# (0.442941, 11)
# (0.419629, 7)
# (0.417427, 15)
# (0.365493, 1)
# (0.365099, 9)
# (0.35268, 2)
# (0.337164, 14)
# (0.250017, 4)
# (0.124961, 13)
# (0.110426, 5)
# (0.09904, 6)

# %% [markdown]
# ### ANOVA f-test

# %%
# example of anova f-test feature selection for numerical data
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from matplotlib import pyplot

def select_features(X_train, y_train, X_test):
	# configure to select all features
	fs = SelectKBest(score_func=f_classif, k='all')
	# learn relationship from training data
	fs.fit(X_train, y_train)
	# transform train input data
	X_train_fs = fs.transform(X_train)
	# transform test input data
	X_test_fs = fs.transform(X_test)
	return X_train_fs, X_test_fs, fs

X_train, X_test, y_train, y_test = train_test_split(df_balanced_stand, y_balanced, test_size=0.33, random_state=1)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)
# what are scores for the features
for i in range(len(fs.scores_)):
	print('Feature %d: %f' % (i, fs.scores_[i]))
# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# Feature 0: 50.321009
# Feature 1: 21.766760
# Feature 2: 2.674894
# Feature 3: 113.454260
# Feature 4: 1288.652767
# Feature 5: 829.958209
# Feature 6: 17.271605
# Feature 7: 10564.085637
# Feature 8: 22.467078
# Feature 9: 4414.205413
# Feature 10: 85.724694
# Feature 11: 1195.442968
# Feature 12: 180.148088
# Feature 13: 490.009037
# Feature 14: 1232.540399
# Feature 15: 3909.374729
# Feature 16: 9839.200705
# Feature 17: 3490.117131

# %%
fs.scores_
ind = 1
tup = []
for i in fs.scores_:
    tup.append((round(i,2),ind))
    ind +=1

tup.sort()   
# Retorna as features priorizadas
for i in reversed(tup):
    print(i)
# Out:
# (10564.09, 8)
# (9839.2, 17)
# (4414.21, 10)
# (3909.37, 16)
# (3490.12, 18)
# (1288.65, 5)
# (1232.54, 15)
# (1195.44, 12)
# (829.96, 6)
# (490.01, 14)
# (180.15, 13)
# (113.45, 4)
# (85.72, 11)
# (50.32, 1)
# (22.47, 9)
# (21.77, 2)
# (17.27, 7)
# (2.67, 3)

# %% [markdown]
# # INICIO DA PREDIÇÃO

# %%
import numpy as np # Numpy: biblioteca para manipular vetores e matrizes
import pandas as pd # Pandas: biblioteca para manipular tabelas
import scipy.stats as ss

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

from sklearn.pipeline import Pipeline

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.feature_selection import VarianceThreshold, SelectKBest
from sklearn.decomposition import PCA

from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import make_scorer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-25a56bb3f532> in <module>
# ----> 1 print(data.shape)
#
# NameError: name 'data' is not defined
